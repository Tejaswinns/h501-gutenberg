# %%
from tt_gutenberg.utils import load_languages
print(load_languages().columns)
# Out:
# Index(['gutenberg_id', 'language', 'total_languages'], dtype='object')

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                   C:\Users\tejas\miniconda3
#                        C:\Users\tejas\miniconda31
#                      * C:\Users\tejas\miniconda31\envs\h501-gutenberg

# %%
from tt_gutenberg.authors import list_authors

aliases = list_authors()
print(aliases)
# Out:
# ['Grimm, Wilhelm Carl', 'Grimm, Jacob Ludwig Carl', 'Andersen, Hans Christian', 'Alighieri, Dante', 'Stevenson, R. L. (Robert Louis)', "Wilde, Oscar Fingal O'Flahertie Wills", 'Poe, Edgar Allen', 'Όμηρος', 'Chaney, John Griffith', 'De Maupassant, Guy', 'Dodgson, Charles Lutwidge', 'Πλάτων', 'Swift, J. (Jonathan)', 'Darwin, Charles Robert', 'Descartes, Rene', 'Gloux, Olivier', 'Crayon, Geoffrey', 'Rollan, R.', 'Von Schmid, Christoph', 'Wells, Herbert George', 'Curwood, James-Oliver', 'Engels, Frederick', 'Malot, Hector-Henri', 'Merimee, Prosper', 'Michelet, J.', 'Mill, J. S. (John Stuart)', 'Murger, Henry', 'Ohnet, Jorge', 'Branch, Stephen', 'Racine, Jean Baptiste', 'Reuter, Heinrich Ludwig Christian Friedrich', 'Harte, Francis Bret', 'Ruskin, J. (John)', 'Augustine, Saint', 'Erasmus, of Rotterdam', 'Strindberg, Johan August', 'Daudet, Louis Marie Alphonse', 'Bunyan, Johann', '孔子', 'Buonarroti, Michelangelo', 'Whitman, Walter', 'Chaucer, Jeffrey', 'Heine, H. (Heinrich)', 'Wallace, Lew
# ...
